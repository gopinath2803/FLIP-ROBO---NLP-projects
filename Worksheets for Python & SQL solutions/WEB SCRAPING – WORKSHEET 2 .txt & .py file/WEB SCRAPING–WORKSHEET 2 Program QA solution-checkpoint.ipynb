# %% [markdown]
# # WORKSHEET :
# Q14 and Q15 are programming practice questions. Solve it using JUPYTER NOTEBOOK.(solved in .ipynb file)
#
# 14. Write a python program to scrap 10 images of Rayban Sunglasses from flipkart website and save them in a
# directory.

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait as wdt
from selenium.common.exceptions import StaleElementReferenceException as ser
from selenium.webdriver.support import expected_conditions as ec
import time
import os,requests,pandas as pd
import random

# %%
def directory(directory_name):
    CurrentPath=os.getcwd()
    path=os.path.join(CurrentPath,directory_name)
    if not os.path.exists(path):
        os.makedirs(path)
    print('Directory {0} has been Created\n\n'.format(directory_name))

# %%
def scrapper(driver,directory,number):
    
#IMAGE SAVING

    im= str(input("Enter the X_path locator of image:::\t"))
    img=driver.find_elements_by_xpath(im)
    
    links=[]
    
    for image in img:
        source=image.get_attribute('src')
        links.append(source)
    print('\nTotal links found',len(links))
    
    download=random.sample(links,number) #selecting randomly required numbers of list to download
    print("No of images to be downloaded=\t",len(download))
    
    import shutil
    import requests
    for index,link in enumerate(download):
       
        print('\nGetting ', index+1,'of', len(download),'Images from the Page to the Local Machine')

        response=requests.get(link)
    
        with open('{0}/ FLIPKART_{1}_{2}.jpeg'.format(directory,directory,index+1), 'wb+') as doc:
            doc.write(response.content)

# %%
chrome_options = webdriver.ChromeOptions()
prefs = {"profile.default_content_setting_values.notifications" : 2}
chrome_options.add_experimental_option("prefs",prefs)
#this news paper is generating warning so to disable it........

driver=webdriver.Chrome(executable_path=r"C:\Users\software\chromedriver.exe")

# %%
URL= "https://www.flipkart.com/"
driver.get(URL)
time.sleep(10)
wait=wdt(driver,14)

element=wait.until(ec.element_to_be_clickable((By.XPATH,"//input[@class='LM6RPg']")))
element.click()

element.send_keys('Rayban Sunglasses')
driver.find_element_by_class_name('vh79eN').click()
time.sleep(7)

#creating directory
directory(directory_name= "sunglass")

#"//img[@class='_3togXc']"

try:
    scrapper(driver=driver,directory='sunglass',number=10)                   
    time.sleep(6)
    driver.find_element_by_xpath("//a[@class='_3fVaIS']").click() #next page
    
except ser:
    print("WE ARE FACING UNANTED EXCEPTION.RESTARTING THE SERVICE..\n\n")
    error_page=driver.find_element_by_xpath("//a[@class=_3fVaIS]").text
    print('Exceptions Faced at',error_page)
    value=driver.find_element_by_xpath("//a[@class='_3fVaIS']")
    link=value.get_attribute('href')
    driver.get(link)
    scrapper(driver=driver,directory=sunglass,number=10)
    time.sleep(6)
    print(" Moving to Next Page")
    driver.find_element_by_xpath("//a[@class='_3fVaIS']").click()
# Out:
# Directory sunglass has been Created
#
#
# Enter the X_path locator of image:::	//img[@class='_3togXc']
#
# Total links found 40
# No of images to be downloaded=	 10
#
# Getting  1 of 10 Images from the Page to the Local Machine
#
# Getting  2 of 10 Images from the Page to the Local Machine
#
# Getting  3 of 10 Images from the Page to the Local Machine
#
# Getting  4 of 10 Images from the Page to the Local Machine
#
# Getting  5 of 10 Images from the Page to the Local Machine
#
# Getting  6 of 10 Images from the Page to the Local Machine
#
# Getting  7 of 10 Images from the Page to the Local Machine
#
# Getting  8 of 10 Images from the Page to the Local Machine
#
# Getting  9 of 10 Images from the Page to the Local Machine
#
# Getting  10 of 10 Images from the Page to the Local Machine

# %% [markdown]
# 15. Write a program to scrap 20 mouses’ data which includes model name, price from www.amazon.in whose price
# is less than 500 and make a data frame with 2 columns “model_name”,” price” with the scraped data.

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait as wdt
from selenium.common.exceptions import StaleElementReferenceException as ser
from selenium.webdriver.support import expected_conditions as ec
import time

import os,requests,pandas as pd

# %%
#scrapping details
mouse={}

mouse['model_name']=[] #for name of brand of the mouse
mouse['price']=[] #for price of the mouse
brands=[]
prices=[]
def scrapper(driver):
       
    driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
    time.sleep(12)

    
    temp1=driver.find_elements_by_xpath("//a[@class='a-link-normal a-text-normal']/span")
    temp2=driver.find_elements_by_class_name('a-price-whole')
   
    brands=temp1[1:21]
    prices=temp2[1:21]
    
    
    for i in brands:
        mouse['model_name'].append(i.text)
    
    
    for j in prices:
        mouse['price'].append(j.text)

# %%
chrome_options = webdriver.ChromeOptions()
prefs = {"profile.default_content_setting_values.notifications" : 2}
chrome_options.add_experimental_option("prefs",prefs)


driver=webdriver.Chrome(executable_path=r"C:\Users\software\chromedriver.exe",options=chrome_options)

# %%
driver.get('https://www.amazon.in/')
time.sleep(10)
wait=wdt(driver,14)
element=wait.until(ec.element_to_be_clickable((By.XPATH,"//*[@id='twotabsearchtextbox']"))) #input box
element.click()
element.send_keys('mouse')
driver.find_element_by_class_name('nav-input').click()
time.sleep(7)


#setting price at 500
wait.until(ec.presence_of_all_elements_located((By.ID,"priceRefinements"))) #price box
price_box=driver.find_element_by_id("high-price") #locating the max price box
price_box.send_keys('500')  #entering the value of max price
driver.find_element_by_id('a-autoid-1').click()  #selecting go button and clicking on it
time.sleep(6)


try:
    scrapper(driver=driver)                   
        
except ser:
    print("WE ARE FACING UNANTED EXCEPTION.RESTARTING THE SERVICE..\n\n")

# %%
print("models=",mouse['model_name'],'\n\nprice=',mouse['price'])
# Out:
# models= ['Logitech M337 Wireless Mouse, Bluetooth, 1000 DPI Laser Grade Optical Sensor, 10-Month Battery Life, PC/Mac/Laptop - Black', 'HP X1000 Wired Mouse (Black/Grey)', 'Lenovo 300 Wired USB Mouse, GX30M39704', 'Logitech M90 Wired USB Mouse, 1000 DPI Optical Tracking, Ambidextrous PC/Mac/Laptop - Black', 'HP X1000 Wired Mouse (Black/Grey)', 'Dell MS116 1000DPI USB Wired Optical Mouse', '', '', 'Xmate Zorro Wired USB Gaming Mouse, 3200 DPI Optical Sensor, RGB Lighting, 6 Mechanical Buttons, Lightweight & Durable Mouse for PC/Laptop/Mac - (Black)', 'Logitech M235 Wireless Mouse for Windows and Mac with 2.4 GHz Wireless Technology - Black/Grey', 'Ant Esports GM200W Gaming Mouse Wired, 6 Programmable Buttons, 3200 DPI Adjustable, with 7 Breathing Lights, Comfortable Grip Ergonomic Optical PC Computer Gaming Mouse, World of Warships Edition – Black', 'Dell Ms116 275-BBCB Optical Mouse', 'Logitech M221 Wireless Mouse, Silent Buttons, 2.4 GHz with USB Mini Receiver, 1000 DPI Optical Tracking, 18-Month Battery Life, Ambidextrous PC/Mac/Laptop - Charcoal Grey', 'Portronics Toad 12 Wireless 2.4G Optical Mouse with Ergonomic Design, USB Receiver for Notebook, Laptop, Computer, MacBook, Windows, MacOS, (Blue)', 'Zebronics Zeb-Rise Wired USB Optical Mouse with 3 Buttons (Black)', 'Xmate Rio Wired USB Gaming Mouse, Led Backlit, 6 Button, 7 Color Breathing Lights, High Ergonomic Mouse, Durable ABS Body for Computer PC & Laptop, 1.5M Nylon Braided Cable (Black)', 'HP 200 Wireless Mouse (Black)', 'Dell MS116 1000DPI USB Wired Optical Mouse', 'Zinq Technologies ZQ233 Wired Mouse with 1000DPI for Laptop and Desktop (Black)', 'Portronics Toad 12 Wireless 2.4G Optical Mouse with Ergonomic Design, USB Receiver for Notebook, Laptop, Computer, MacBook, Windows, MacOS, (Blue)']
#
# price= ['1,424', '349', '299', '299', '349', '404', '', '', '499', '799', '449', '349', '824', '477', '229', '399', '715', '404', '199', '477']

# %%
driver.quit()

# %%
df=pd.DataFrame(mouse)
df
# Out:
#                                            model_name  price
# 0   Logitech M337 Wireless Mouse, Bluetooth, 1000 ...  1,424
# 1                   HP X1000 Wired Mouse (Black/Grey)    349
# 2              Lenovo 300 Wired USB Mouse, GX30M39704    299
# 3   Logitech M90 Wired USB Mouse, 1000 DPI Optical...    299
# 4                   HP X1000 Wired Mouse (Black/Grey)    349
# 5          Dell MS116 1000DPI USB Wired Optical Mouse    404
# 6
# 7
# 8   Xmate Zorro Wired USB Gaming Mouse, 3200 DPI O...    499
# 9   Logitech M235 Wireless Mouse for Windows and M...    799
# 10  Ant Esports GM200W Gaming Mouse Wired, 6 Progr...    449
# 11                  Dell Ms116 275-BBCB Optical Mouse    349
# 12  Logitech M221 Wireless Mouse, Silent Buttons, ...    824
# 13  Portronics Toad 12 Wireless 2.4G Optical Mouse...    477
# 14  Zebronics Zeb-Rise Wired USB Optical Mouse wit...    229
# 15  Xmate Rio Wired USB Gaming Mouse, Led Backlit,...    399
# 16                      HP 200 Wireless Mouse (Black)    715
# 17         Dell MS116 1000DPI USB Wired Optical Mouse    404
# 18  Zinq Technologies ZQ233 Wired Mouse with 1000D...    199
# 19  Portronics Toad 12 Wireless 2.4G Optical Mouse...    477

# %% [markdown]
# # Result :
#     ---> We have proved Q14 and Q15 are practice questions
